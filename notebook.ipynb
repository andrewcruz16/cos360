# %% [markdown]
# # COS360 - Otimização - Trabalho Final

# %% [markdown]
# ## Libs

# %%
#!pip install sympy

# %%
import math
import random
import time

import numpy as np
import sympy as sym
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import HTML, display
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Estudo da função

# %%
def gradient(x):
    return np.array([
        1 - 2 * x[0] / (2 * (x[0] - 1) * x[0] * np.sqrt(-1 * np.log((x[0] - 1) * x[0] * (x[1] - 1) * x[1]))),
        1 - 2 * x[1] / (2 * (x[1] - 1) * x[1] * np.sqrt(-1 * np.log((x[0] - 1) * x[0] * (x[1] - 1) * x[1])))
    ])

# %%
def armijo_search(x0, d, k):
    eta = 0.6
    gamma = 0.8
    t = 1

    while function(np.array(x0) + np.array(d) * t) > f(x0) + eta * t * np.dot(gradient(x0).transpose(), d):
        k += 1
        t = gamma * t

    return t, k

# %%
def hessian(x):
    return np.array([

    ])

# %%
def function(x):
    return np.sqrt(-1 * math.log(x[0] * (1 - x[0]) * x[1] * (1 - x[1])))

# %%
x = y = np.linspace(0.1, 0.9, 10)
X, Y = np.meshgrid(x, y)

z_array = np.array([function([a, b]) for a, b in zip(np.ravel(X), np.ravel(Y))])
Z = z_array.reshape(X.shape)

fig = plt.figure(figsize=[10.0,10.0])
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %% [raw]
# 𝑓(𝑥1,𝑥2)=−√ (ln(𝑥1(1−𝑥1)𝑥2(1−𝑥2)))

# %% [markdown]
# ## Minimização

# %%
def gradient_method(x0):
    k = 0
    k_armijo = 0
    
    while gradient(x0).any(): # While some element !== 0
        d = -1 * gradient(x0)
        t, k_armijo = armijoSearch(x0, d, k_armijo)
        x0 = np.array(x0) + t*d
        k += 1
        
        if (getGradient(x0) == -1*d).all():
#             print('delta == 0')
            break

        if np.linalg.norm(getGradient(x0)) <= 10**-15:
#             print('gradient close to 0')
            break
        
    return np.array(x0), k, k_armijo
